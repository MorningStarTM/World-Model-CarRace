# %%
# !git clone https://github.com/MorningStarTM/World-Model-CarRace.git
# Out:
# Cloning into 'World-Model-CarRace'...
# remote: Enumerating objects: 305, done.
# remote: Counting objects: 100% (305/305), done.
# remote: Compressing objects: 100% (163/163), done.
# remote: Total 305 (delta 143), reused 273 (delta 118), pack-reused 0 (from 0)
# Receiving objects: 100% (305/305), 5.06 MiB | 38.68 MiB/s, done.
# Resolving deltas: 100% (143/143), done.

# %%
 # %cd /kaggle/working/World-Model-CarRace
# Out:
# /kaggle/working/World-Model-CarRace

# %%
from world_model.ae.autoencoder import Autoencoder
from world_model.data.memory_data import MemoryData
import matplotlib.pyplot as plt
import cv2
import os
import torch

# %%
ae = Autoencoder()
ae.load(encoder_path="/kaggle/working/World-Model-CarRace/world_model/models/autoencoder/encoder.pth", 
        decoder_path="/kaggle/working/World-Model-CarRace/world_model/models/autoencoder/decoder.pth")
ae.to(ae.device)
# Out:
# /kaggle/working/World-Model-CarRace/world_model/ae/autoencoder.py:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.load_state_dict(torch.load(path))
# ...

# %%
md = MemoryData(model=ae, image_folder="/kaggle/input/data-generator/car_racing-memory-model", 
                csv_file='/kaggle/input/data-generator/car_racing-memory-model/episode_data.csv')

# %%
md.process_and_save("/kaggle/working/memorydata.csv")
# Out:
# Skipping images0_499.png as the next image images0_500.png does not exist.
# Skipping images1_499.png as the next image images1_500.png does not exist.
# Skipping images2_499.png as the next image images2_500.png does not exist.
# Skipping images3_499.png as the next image images3_500.png does not exist.
# Skipping images4_499.png as the next image images4_500.png does not exist.
# Skipping images5_499.png as the next image images5_500.png does not exist.
# Skipping images6_499.png as the next image images6_500.png does not exist.
# Skipping images7_499.png as the next image images7_500.png does not exist.
# Skipping images8_499.png as the next image images8_500.png does not exist.
# Skipping images9_499.png as the next image images9_500.png does not exist.
# Skipping images10_499.png as the next image images10_500.png does not exist.
# Skipping images11_499.png as the next image images11_500.png does not exist.
# ...

# %%
import pandas as pd
df = pd.read_csv("/kaggle/working/memorydata.csv")
df.shape
# Out:
# (49900, 3)
